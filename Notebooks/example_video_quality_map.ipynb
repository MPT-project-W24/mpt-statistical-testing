# %%
# Importing the video_quality_map.py package
from video_quality_map import merge_data, trajectory_plot, zoom_trajectory_plot, distruibution_by_age

# The files inputs - Path to json file, msd directory, and feature directory
json_path = '/Users/khanhha/mpt-statistical-testing/MPTData/15_models_10_percent.json'
msd_path = '/Users/khanhha/mpt-statistical-testing/MPTData/msd_data'
feature_path = '/Users/khanhha/mpt-statistical-testing/MPTData/feature_data'

# %%
[merge_df, msd_data, quality_data] = merge_data(feature_path, msd_path, json_path)

# %%
vid_code = 'P21_40nm_s1_v1'
trajectory_plot(merge_df, vid_code)

# %%
zoom_trajectory_plot(merge_df, vid_code, 700, 750, 1250, 1150)

# %%
distruibution_by_age(feature_path, msd_path, quality_data)

# %%
# Plot and Save as image
vid_code = 'P21_40nm_s2_v2'
trajectory_plot(merge_df, vid_code, 0)

# %%
zoom_trajectory_plot(merge_df, vid_code, 500, 750, 250, 500, 0)

# %%
distruibution_by_age(feature_path, msd_path, quality_data, 0)
